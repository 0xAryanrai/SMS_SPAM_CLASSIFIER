# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('spam.csv', encoding='latin1')

# %%
df.sample(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 3673  spam  You have won a Nokia 7250i. This is what you g...        NaN
# 3070   ham     Apart from the one i told you about yesterday?        NaN
# 5275   ham                      Oh yeah clearly it's my fault        NaN
# 3847   ham  Can you plz tell me the ans. BSLVYL sent via f...        NaN
# 4482   ham  True lov n care wil nevr go unrecognized. thou...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 3673        NaN        NaN
# 3070        NaN        NaN
# 5275        NaN        NaN
# 3847        NaN        NaN
# 4482        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
# total expected steps to be performed -->
#1) Data cleaning - removing useless NAN values
#2) EDA - exploratory data analysis
#3) Text preprocessing -  vectorization , stemming, etc
#4)model building 
#5) evaluation of the model built
#6) improvement based on model evaluation metrics
#7) website
#8) deploy the website on hirauku

# %% [markdown]
# 1) Data cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
# since most of the values in last three columns are null so these columns are not much useful
# so, we will remove these column
df.drop(columns = ['Unnamed: 2' ,'Unnamed: 3','Unnamed: 4'], inplace = True)

# %%
df.sample(5)
# Out:
#         v1                                                 v2
# 4154  spam  Want a new Video Phone? 750 anytime any networ...
# 784    ham  Dont think so. It turns off like randomlly wit...
# 4327  spam  Congrats! 2 mobile 3G Videophones R yours. cal...
# 655    ham      Tell them the drug dealer's getting impatient
# 1833   ham                           When should I come over?

# %%
#renaming the columns
df.rename(columns = {'v1' : 'target', 'v2' : 'text'},inplace=True)

# %%
df.sample(5)
# Out:
#      target                                               text
# 804     ham                          K I'll be there before 4.
# 3106    ham  Hi. Happy New Year. I dont mean to intrude but...
# 3193    ham  And you! Will expect you whenever you text! Ho...
# 4193    ham        Can not use foreign stamps in this country.
# 1146    ham                          Babe ? I lost you ... :-(

# %%
# the target is given as spam or ham but we need numbers to classify , so we use label encoder from sklearn
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])  #this assign ham as 0 and spam as 1

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
#missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
#check for duplicate values
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
#now removing duplicate values
df.drop_duplicates(keep = 'first')
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %%
df.shape
# Out:
# (5572, 2)

# %% [markdown]
# 2) Performing EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
# Out:
# target
# 0    4825
# 1     747
# Name: count, dtype: int64

# %%
#display the percentage of spam v/s ham 
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts() , labels =['ham','spam'],autopct = "%0.2f")
plt.show()

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\aryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
#now checking the no. of character , words ,etc in each of the text
df['num_character']=df['text'].apply(len)
df.head()
# Out:
#    target                                               text  num_character
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61

# %%
#no. of words 
df['text'].apply(lambda x:len(nltk.word_tokenize(x)))
# Out:
# 0       24
# 1        8
# 2       37
# 3       13
# 4       15
#         ..
# 5567    35
# 5568     9
# 5569    15
# 5570    27
# 5571     7
# Name: text, Length: 5572, dtype: int64

# %%
df['num_words'] = df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
df['num_sentence']=df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61
#
#    num_words  num_sentence
# 0         24             2
# 1          8             2
# 2         37             2
# 3         13             1
# 4         15             1

# %%
df[['num_character','num_words','num_sentence']].describe()
# Out:
#        num_character    num_words  num_sentence
# count    5572.000000  5572.000000   5572.000000
# mean       80.118808    18.699390      1.996411
# std        59.690841    13.741932      1.520159
# min         2.000000     1.000000      1.000000
# 25%        36.000000     9.000000      1.000000
# 50%        61.000000    15.000000      1.500000
# 75%       121.000000    27.000000      2.000000
# max       910.000000   220.000000     38.000000

# %%
#describe() for ham message only
df[df['target'] == 0][['num_character','num_words','num_sentence']].describe()
# Out:
#        num_character    num_words  num_sentence
# count    4825.000000  4825.000000   4825.000000
# mean       71.023627    17.276269      1.837720
# std        58.016023    13.988585      1.454388
# min         2.000000     1.000000      1.000000
# 25%        33.000000     8.000000      1.000000
# 50%        52.000000    13.000000      1.000000
# 75%        92.000000    22.000000      2.000000
# max       910.000000   220.000000     38.000000

# %%
#describe() for spam messages
df[df['target'] == 1][['num_character','num_words','num_sentence']].describe()
# Out:
#        num_character   num_words  num_sentence
# count     747.000000  747.000000    747.000000
# mean      138.866131   27.891566      3.021419
# std        29.183082    6.867007      1.537580
# min        13.000000    2.000000      1.000000
# 25%       132.500000   25.000000      2.000000
# 50%       149.000000   29.000000      3.000000
# 75%       157.000000   32.000000      4.000000
# max       224.000000   46.000000      9.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,7))
sns.histplot(df[df['target']==0]['num_words'])
sns.histplot(df[df['target']==1]['num_character'] ,color ='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_character  num_words  num_sentence
# 0               111         24             2
# 1                29          8             2
# 2               155         37             2
# ...

# %% [markdown]
# 3)DATA PREPROCESSING
# -->lowercase
# -->removing special characters
# -->removing stop words and punctuation
# -->stemming

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import nltk 
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# now we perform stemming
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
def transform_text(text):
    text = text.lower()#converting the text to lower case
    text = nltk.word_tokenize(text)#this breaks the sentence into tokens 

    y=[]
    for i in text:  #to remove special characters
        if i.isalnum():
            y.append(i)

    text = y[:]
    y.clear()

    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)

    text = y[:]
    y.clear()

    for i in text:
        y.append(ps.stem(i))
        

    return " ".join(y)

# %%
transform_text('I loved Watching YT Shorts.')
# Out:
# 'love watch yt short'

# %%
df['text'].apply(transform_text)
# Out:
# 0       go jurong point crazi avail bugi n great world...
# 1                                   ok lar joke wif u oni
# 2       free entri 2 wkli comp win fa cup final tkt 21...
# 3                     u dun say earli hor u c alreadi say
# 4                    nah think goe usf live around though
#                               ...
# 5567    2nd time tri 2 contact u pound prize 2 claim e...
# 5568                                b go esplanad fr home
# 5569                                    piti mood suggest
# 5570    guy bitch act like interest buy someth els nex...
# 5571                                       rofl true name
# Name: text, Length: 5572, dtype: object

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61
#
#    num_words  num_sentence                                   transformed_text
# 0         24             2  go jurong point crazi avail bugi n great world...
# 1          8             2                              ok lar joke wif u oni
# 2         37             2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13             1                u dun say earli hor u c alreadi say
# 4         15             1               nah think goe usf live around though

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
wc = WordCloud(width = 500,height = 500,min_font_size = 10, background_color='white')

# %%
wc.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))

# %%
spam_wc = wc.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))

# %%
plt.imshow(spam_wc)  #displays those words that mostly occur in a spam message

# %%
ham_wc = wc.generate(df[df['target']==0]['transformed_text'].str.cat(sep=" "))

# %%
plt.imshow(ham_wc)

# %% [markdown]
# 4) Model building--

# %%
from sklearn.feature_extraction.text import CountVectorizer#since our input is text and we need to pass numerical data to model so we use vectorizsation
cv = CountVectorizer()

# %%
X= cv.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5572, 6708)

# %%
y = df['target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(5572,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb=GaussianNB()
mnb = MultinomialNB()
bnb= BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.873542600896861
# [[843 114]
#  [ 27 131]]
# 0.5346938775510204

# %%
bnb.fit(X_train,y_train)
y_pred2 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9695067264573991
# [[956   1]
#  [ 33 125]]
# 0.9920634920634921

# %%
mnb.fit(X_train,y_train)
y_pred3 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9713004484304932
# [[942  15]
#  [ 17 141]]
# 0.9038461538461539

# %%
#so mnb is working the best
